# %% [markdown]
# <img style="float: left; margin: 30px 15px 15px 15px;" src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTFzQj91sOlkeDFkg5HDbjtR4QJYmLXkfMNig&usqp=CAU" width="400" height="500" />
#
#
# ### <font color='navy'> Simulación matemática.
#
# **Nombres:** María del Carmen Martínez Hernández.
#
# **Fecha:** 10 de octubre del 2022.
#
# **Expediente** : NT729340.
#
# **Profesor:** Oscar David Jaramillo Zuluaga.
#
# **Link Github**:https://github.com/MMHdez/T6MariaMartinez
#
# # Tarea 5: Clase 10

# %% [markdown]
# ## TAREA 5
# > 1. Realizar las siguientes integrales. Poner los resultados en una tabla cuyas filas correspondan a la cantidad de términos utilizados en la aproximación (usar 10, 100, 1000, 10000 y 100000 términos) y cuyas columnas correspondan a las funciones.
#     + $\int_{1}^{5} \log_{10}(2x)+8^x\text{d}x$.
#     + $\int_1^5 \frac{2^x}{x^4} \text{d}x$
#
# **Entregable: se debe subir un archivo con extensión .ipnyb y nombrarlo con el formato T6PrimerNombrePrimerApellido.ipynb**

# %%
# importar librería numpy
import numpy as np

# Importar librería pandas
import pandas as pd

# %%
# Escribir la función
def montecarlo1(f, a, b, N):

# Generar N puntos uniformemente distribudos en el intervalo [a,b)
    ui = np.random.uniform(a, b, N)
    
# Evaluar la función en los N puntos aleatorios, obtener el promedio y multiplicarlo por el intervalo
    integral = ((b-a)/N)*np.sum(f(ui))
    
# integral = (b-a)*np.mean(f(ui)) Esta línea es equivalente a la anterior
    return integral

# %%
# Resolver

# 1. Definir las funciones a integrar
def f1(x):
    return np.log10(2*x) + 8**x

def f2(x):
    return 2**x / x**4

# 2. Definir los límites de integración
a, b = 1, 5

# 3. Definir cantidad de términos
N = np.logspace(0, 5, 6).astype(int)

# %%
# Crear el DataFrame de pandas (tabla) que contendrá la información
tabla1 = pd.DataFrame(index=N, columns = ['Aprox f1', 'Aprox f2'])

# Agregar nombre al índice para que aprezca en la tabla
tabla1.index.name = 'Cantidad de términos'

VR1 = 15757 

VR2 = 1.00931

# Rellenar las celdas de la aproximación de cada función
for n in N:
    aprox_f1 = montecarlo1(f1, a, b, n)
    aprox_f2 = montecarlo1(f2, a, b, n)  
    
    tabla1.loc[n, 'Aprox f1'] = aprox_f1
    tabla1.loc[n, 'Aprox f2'] = aprox_f2
    
tabla1['Error f1'] = 100*np.abs(tabla1['Aprox f1']-VR1)/VR1

tabla1['Error f2'] = 100*np.abs(tabla1['Aprox f2']-VR2)/VR2
        
tabla1
# Out:
#                           Aprox f1  Aprox f2    Error f1   Error f2
# Cantidad de términos
# 1                     37268.630922  0.331811  136.521108  67.124996
# 10                     14998.28132  0.475797    4.815121  52.859147
# 100                    18346.08088  1.010634   16.431306   0.131205
# 1000                  17116.309014   1.09501    8.626699   8.490988
# 10000                 15977.566129   1.00575    1.399798   0.352727
# 100000                15870.125503  1.008628    0.717938   0.067575

# %% [markdown]
# **Conclusión:** Los resultados de las integrales son los siguientes:
#
# $$\int_{1}^{5} \log_{10}(2x)+8^x\text{d}x \approx 15757 $$
#
# $$\int_1^5 \frac{2^x}{x^4} \text{d}x \approx 1.00931 $$
#
# Por lo tanto el método es adecuado (recordando que a mayor cantidad de términos mejor se acercará el valor aproximado al valor real).
